# %% [markdown]
# # Exploratory Data Analysis for Cars93 Dataset

# %% [markdown]
# We do Exploratory Data Analysis
# to Get deeper understanding of Data
#
# Column|Feature Types
# Quantitative[Continous]
# (Contains values that can quantified|measure) Numeric --> quantified|measure(Jisko aap measure kar sakte ho)
# Age, Height, Salary, Mileage, Weight, temperature
#
#
# Qualitative(Categories)[Catgeorical]
# gender, Season, STATE, Type of Car, Taste, Color, Blood Group

# %%
from pandas import read_csv
A = read_csv("C:/Dataset/Dataset/Cars93.csv")

# %%
A.head(6)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
# 5   6        Buick  Century  Midsize       14.2   15.7       17.3        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# ...

# %% [markdown]
# # Univariate Analysis:
# Analysis of a single variable|column|feature

# %%
A.Type.unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
A.Type.value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
A.groupby(by="Type")['Manufacturer'].count()
# Out:
# Type
# Compact    16
# Large      11
# Midsize    22
# Small      21
# Sporty     14
# Van         9
# Name: Manufacturer, dtype: int64

# %%
A.Type.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
A.Type.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
A.Type.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Type'>

# %%
A.Manufacturer.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Manufacturer'>

# %%
A.Manufacturer.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
A.Price.hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sb
from warnings import filterwarnings
filterwarnings("ignore")

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,3,1)
sb.countplot(A.Type)

plt.subplot(2,3,2)
sb.countplot(A.Origin)

plt.subplot(2,3,3)
sb.countplot(A.Cylinders)

plt.subplot(2,3,4)
sb.countplot(A.Passengers)

plt.subplot(2,3,5)
sb.countplot(A.AirBags)

plt.subplot(2,3,6)
sb.countplot(A.DriveTrain)
# Out:
# <AxesSubplot:xlabel='DriveTrain', ylabel='count'>

# %%
cat = []
con = []

# %%
for i in A.columns:
    if(A[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con
# Out:
# ['id',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
A[con].head()
# Out:
#    id  Min.Price  Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# 0   1       12.9   15.9       18.8        25           31         1.8
# 1   2       29.2   33.9       38.7        18           25         3.2
# 2   3       25.9   29.1       32.3        20           26         2.8
# 3   4       30.8   37.7       44.6        19           26         2.8
# 4   5       23.7   30.0       36.2        22           30         3.5
#
#    Horsepower   RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  Length  \
# 0         140  6300          2890                13.2           5     177
# 1         200  5500          2335                18.0           5     195
# 2         172  5500          2280                16.9           5     180
# 3         172  5500          2535                21.1           6     193
# 4         208  5700          2545                21.1           4     186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  Weight
# ...

# %% [markdown]
# # Create countplot|bar chart for all categorical variables in 1 figure area

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
plt.figure(figsize=(20,20))

x = 1
for i in cat:
    plt.subplot(3,3,x)
    sb.countplot(A[i])
    x = x+1

# %%
plt.figure(figsize=(20,12))

x = 1
for i in con:
    plt.subplot(3,7,x)
    A[i].hist()
    x = x+1

# %%
len(con)
# Out:
# 19

# %% [markdown]
# # Bivariate Analysis:

# %% [raw]
# Analysis of relationship between more than 2 variables|columns|features

# %% [raw]
# Scatter plot using matplotlib

# %%
import matplotlib.pyplot as plt
plt.scatter(A.Price,A.Weight)

# %%
plt.scatter(A.Price,A.Weight)
plt.xlabel("Price of the car")
plt.ylabel("Weight of the car")
plt.title("Price vs Weight scatterplot")
# Out:
# Text(0.5, 1.0, 'Price vs Weight scatterplot')

# %%
for i in A.columns:
    if(A[i].dtypes=="object"):
        sb.countplot(A.Origin,hue=A[i])      #Countplot with hue between categorical and categorical columns
        plt.ylabel(i)
        plt.show()

# %% [markdown]
# # Multivariate Analysis

# %% [raw]
# Analysis of relationship between more than 2 variables|columns|features

# %%
sb.pairplot(A)    #Pair Plots way to visualize relationships between each variable

# %%
import seaborn as sb

# %%
sb.heatmap(A.corr())
# Out:
# <AxesSubplot:>
